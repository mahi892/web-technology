# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("dataframe_hrv.csv")
data
# Out:
#          ECG       EMG          HR       RESP      newtime  stress
# 0  -0.001974 -0.004737   77.815789  10.801842    12.529684       0
# 1   0.002935 -0.004457  101.978261  10.750609    30.503500       0
# 2   0.006745 -0.003426  104.957447  10.557234    52.523021       0
# 3  -0.004043 -0.002532   87.702128  10.640128    74.402170       0
# 4   0.012745 -0.004426   88.829787  10.699319    96.219617       0
# 5   0.027787 -0.004957   91.404255  10.744000   117.803638       0
# 6  -0.010851 -0.004681   87.319149  10.821277   138.888064       0
# 7  -0.005217 -0.004130   79.521739  11.113217   159.908717       0
# 8  -0.019386 -0.003727   88.022727  10.937545   181.149523       0
# 9  -0.065409 -0.002409   89.863636  11.204727   201.824091       0
# 10 -0.000977 -0.003045   86.909091  11.311909   222.365136       0
# 11 -0.003727 -0.004068   85.272727  10.967727   243.277136       0
# 12  0.018227 -0.003364   81.659091  10.757591   265.347477       0
# ...

# %%
from sklearn import linear_model
from sklearn.linear_model  import LinearRegression

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(data[['ECG','EMG','HR','RESP','newtime']],data.stress)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([  8.32145993e-01,   3.65662787e+00,   1.12513577e-02,
#          5.30796078e-02,   4.05067824e-04])

# %%
reg.intercept_
# Out:
# -1.5385712446536357

# %%
reg.predict([[0.001974,-0.004737,77.815789,10.801842,12.529684]])
# Out:
# array([-0.10028385])

# %%
reg.predict([[0.003319,-0.006255,93.446809,11.543149,1668.803021]])
# Out:
# array([ 0.78140615])

# %%
-0001974.*8.32145993e-01+(-0.004737)*3.65662787e+00+77.815789*1.12513577e-02+10.801842* 5.30796078e-02+12.529684*4.05067824e-04+-1.5385712446536357
# Out:
# -0.10356916160642715

# %%
plt.scatter(data['ECG'],data['HR'],color='red')
plt.title("Stress Detection")
plt.xlabel("ECG")
plt.ylabel("HR")
plt.show()

# %%
plt.scatter(data['ECG'],data['HR'],color='red')
plt.plot(data['ECG'],data['HR'],color='green')
plt.title("Stress Detection")
plt.xlabel("ECG")
plt.ylabel("HR")
plt.show()
